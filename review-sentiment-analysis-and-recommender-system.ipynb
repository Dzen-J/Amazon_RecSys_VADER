# %%
# %pip install vaderSentiment
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->vaderSentiment) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->vaderSentiment) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->vaderSentiment) (2024.7.4)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.2 MB/s eta 0:00:0000:01
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
book_data = pd.read_csv("data/books_data.csv")
book_ratings = pd.read_csv("data/Books_rating.csv")

# %% [markdown]
# # EDA

# %% [markdown]
# Displaying the two Dataframes

# %%
book_data.head()
# Out:
#                                                Title  \
# 0                     Its Only Art If Its Well Hung!
# 1                           Dr. Seuss: American Icon
# 2              Wonderful Worship in Smaller Churches
# 3                      Whispers of the Wicked Saints
# 4  Nation Dance: Religion, Identity and Cultural ...
#
#                                          description              authors  \
# 0                                                NaN     ['Julie Strain']
# 1  Philip Nel takes a fascinating look into the k...       ['Philip Nel']
# 2  This resource includes twelve principles in un...     ['David R. Ray']
# 3  Julia Thomas finds her life spinning out of co...  ['Veronica Haddon']
# 4                                                NaN      ['Edward Long']
#
#                                                image  \
# 0  http://books.google.com/books/content?id=DykPA...
# 1  http://books.google.com/books/content?id=IjvHQ...
# 2  http://books.google.com/books/content?id=2tsDA...
# 3  http://books.google.com/books/content?id=aRSIg...
# 4                                                NaN
#
#                                          previewLink  publisher publishedDate  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...        NaN          1996
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...        NaN          2000
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...  iUniverse       2005-02
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...        NaN    2003-03-01
#
#                                             infoLink  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 4  http://books.google.nl/books?id=399SPgAACAAJ&d...
#
#                       categories  ratingsCount
# 0    ['Comics & Graphic Novels']           NaN
# 1  ['Biography & Autobiography']           NaN
# 2                   ['Religion']           NaN
# 3                    ['Fiction']           NaN
# 4                            NaN           NaN

# %%
book_ratings.head()
# Out:
#            Id                           Title  Price         User_id  \
# 0  1882931173  Its Only Art If Its Well Hung!    NaN   AVCGYZL8FQQTD
# 1  0826414346        Dr. Seuss: American Icon    NaN  A30TK6U7DNS82R
# 2  0826414346        Dr. Seuss: American Icon    NaN  A3UH4UZ4RSVO82
# 3  0826414346        Dr. Seuss: American Icon    NaN  A2MVUWT453QH61
# 4  0826414346        Dr. Seuss: American Icon    NaN  A22X4XUPKF66MR
#
#                           profileName review/helpfulness  review/score  \
# 0               Jim of Oz "jim-of-oz"                7/7           4.0
# 1                       Kevin Killian              10/10           5.0
# 2                        John Granger              10/11           5.0
# 3  Roy E. Perry "amateur philosopher"                7/7           4.0
# 4     D. H. Richards "ninthwavestore"                3/3           4.0
#
#    review/time                                   review/summary  \
# 0    940636800           Nice collection of Julie Strain images
# 1   1095724800                                Really Enjoyed It
# 2   1078790400  Essential for every personal and Public Library
# 3   1090713600  Phlip Nel gives silly Seuss a serious treatment
# 4   1107993600                           Good academic overview
#
#                                          review/text
# 0  This is only for Julie Strain fans. It's a col...
# 1  I don't care much for Dr. Seuss but after read...
# 2  If people become the books they read and if "t...
# 3  Theodore Seuss Geisel (1904-1991), aka &quot;D...
# 4  Philip Nel - Dr. Seuss: American IconThis is b...

# %%
book_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212404 entries, 0 to 212403
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Title          212403 non-null  object
#  1   description    143962 non-null  object
#  2   authors        180991 non-null  object
#  3   image          160329 non-null  object
#  4   previewLink    188568 non-null  object
#  5   publisher      136518 non-null  object
#  6   publishedDate  187099 non-null  object
#  7   infoLink       188568 non-null  object
#  8   categories     171205 non-null  object
#  9   ratingsCount   49752 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 16.2+ MB

# %% [markdown]
# # Pre-Processing

# %% [markdown]
# Cleaning the Data and Pre-Processing

# %%
#Finding Null Values and percentage of Null Values
print(book_data.isnull().sum())
print("\n")
print((book_data.isnull().sum()/(len(book_data)))*100)
# Out:
# Title                 1
# description       68442
# authors           31413
# image             52075
# previewLink       23836
# publisher         75886
# publishedDate     25305
# infoLink          23836
# categories        41199
# ratingsCount     162652
# dtype: int64
#
#
# Title             0.000471
# description      32.222557
# authors          14.789270
# image            24.516958
# previewLink      11.222011
# publisher        35.727199
# publishedDate    11.913617
# infoLink         11.222011
# categories       19.396527
# ratingsCount     76.576712
# dtype: float64

# %%
#Replacing NaN values with 'Unknown' string
book_data['description'].fillna('Unknown', inplace = True)
book_data['authors'].fillna('Unknown', inplace = True)
book_data['image'].fillna('Unknown', inplace = True)
book_data['previewLink'].fillna('Unknown', inplace = True)
book_data['publisher'].fillna('Unknown', inplace = True)
book_data['publishedDate'].fillna('Unknown', inplace = True)
book_data['infoLink'].fillna('Unknown', inplace = True)
book_data['categories'].fillna('Unknown', inplace = True)
# Out:
# /tmp/ipykernel_36/2934237697.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   book_data['description'].fillna('Unknown', inplace = True)
# /tmp/ipykernel_36/2934237697.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   book_data['authors'].fillna('Unknown', inplace = True)
# /tmp/ipykernel_36/2934237697.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   book_data['image'].fillna('Unknown', inplace = True)
# /tmp/ipykernel_36/2934237697.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   book_data['previewLink'].fillna('Unknown', inplace = True)
# /tmp/ipykernel_36/2934237697.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   book_data['publisher'].fillna('Unknown', inplace = True)
# /tmp/ipykernel_36/2934237697.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   book_data['publishedDate'].fillna('Unknown', inplace = True)
# /tmp/ipykernel_36/2934237697.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   book_data['infoLink'].fillna('Unknown', inplace = True)
# /tmp/ipykernel_36/2934237697.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   book_data['categories'].fillna('Unknown', inplace = True)

# %%
book_data.head(15)
# Out:
#                                                 Title  \
# 0                      Its Only Art If Its Well Hung!
# 1                            Dr. Seuss: American Icon
# 2               Wonderful Worship in Smaller Churches
# 3                       Whispers of the Wicked Saints
# 4   Nation Dance: Religion, Identity and Cultural ...
# 5   The Church of Christ: A Biblical Ecclesiology ...
# 6                          The Overbury affair (Avon)
# 7             A Walk in the Woods: a Play in Two Acts
# 8                            Saint Hyacinth of Poland
# 9   Rising Sons and Daughters: Life Among Japan's ...
# 10  Muslim Women's Choices: Religious Belief and S...
# 11                        Dramatica for Screenwriters
# 12   Mensa Number Puzzles (Mensa Word Games for Kids)
# 13  Vector Quantization and Signal Compression (Th...
# 14                               A husband for Kutani
#
#                                           description  \
# 0                                             Unknown
# 1   Philip Nel takes a fascinating look into the k...
# 2   This resource includes twelve principles in un...
# 3   Julia Thomas finds her life spinning out of co...
# 4                                             Unknown
# 5   In The Church of Christ: A Biblical Ecclesiolo...
# 6                                             Unknown
# 7                                             Unknown
# 8   The story for children 10 and up of St. Hyacin...
# 9   Wardell recalls his experience as a foreign st...
# 10  Counters the Western views and stereotypes of ...
# 11  Dramatica for Screenwriters by Armando Saldana...
# 12  Acclaimed teacher and puzzler Evelyn B. Christ...
# 13  Herb Caen, a popular columnist for the San Fra...
# 14  First published in 1938, this is a collection ...
#
#                                      authors  \
# 0                           ['Julie Strain']
# 1                             ['Philip Nel']
# 2                           ['David R. Ray']
# 3                        ['Veronica Haddon']
# 4                            ['Edward Long']
# 5                       ['Everett Ferguson']
# 6                   ['Miriam Allen De Ford']
# 7                           ['Lee Blessing']
# 8                   ['Mary Fabyan Windeatt']
# 9                         ['Steven Wardell']
# 10  ['Camillia Fawzi El-Solh', 'Judy Mabro']
# 11                  ['Armando Salda A-Mora']
# 12                 ['Evelyn B. Christensen']
# 13        ['Allen Gersho', 'Robert M. Gray']
# 14                            ['Frank Owen']
#
#                                                 image  \
# 0   http://books.google.com/books/content?id=DykPA...
# 1   http://books.google.com/books/content?id=IjvHQ...
# 2   http://books.google.com/books/content?id=2tsDA...
# 3   http://books.google.com/books/content?id=aRSIg...
# 4                                             Unknown
# 5   http://books.google.com/books/content?id=kVqRa...
# 6                                             Unknown
# 7                                             Unknown
# 8   http://books.google.com/books/content?id=lmLqA...
# 9                                             Unknown
# 10  http://books.google.com/books/content?id=o7izA...
# 11  http://books.google.com/books/content?id=iTueu...
# 12  http://books.google.com/books/content?id=tX1Is...
# 13  http://books.google.com/books/content?id=GgnrB...
# 14  http://books.google.com/books/content?id=EzxOD...
#
#                                           previewLink  \
# 0   http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1   http://books.google.nl/books?id=IjvHQsCn_pgC&p...
# 2   http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3   http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 4   http://books.google.nl/books?id=399SPgAACAAJ&d...
# 5   http://books.google.nl/books?id=kVqRaiPlx88C&p...
# 6   http://books.google.nl/books?id=mHLTngEACAAJ&d...
# 7   http://books.google.nl/books?id=6HDOwAEACAAJ&d...
# 8   http://books.google.nl/books?id=lmLqAAAACAAJ&d...
# 9   http://books.google.nl/books?id=rbLZugEACAAJ&d...
# 10  http://books.google.nl/books?id=o7izAAAAIAAJ&q...
# 11  http://books.google.nl/books?id=iTueuAAACAAJ&d...
# 12  http://books.google.nl/books?id=tX1IswEACAAJ&d...
# 13  http://books.google.nl/books?id=GgnrBwAAQBAJ&p...
# 14  http://books.google.nl/books?id=EzxODwAAQBAJ&p...
#
#                             publisher publishedDate  \
# 0                             Unknown          1996
# 1                           A&C Black    2005-01-01
# 2                             Unknown          2000
# 3                           iUniverse       2005-02
# 4                             Unknown    2003-03-01
# 5          Wm. B. Eerdmans Publishing          1996
# 6                             Unknown          1960
# 7                             Unknown          1988
# 8                     Tan Books & Pub    2009-01-01
# 9                  Plympton PressIntl          1995
# 10                   Berg Pub Limited    1994-02-17
# 11                            Unknown       2005-07
# 12                           Sky Pony    2018-11-06
# 13  Springer Science & Business Media    2012-12-06
# 14         Pickle Partners Publishing    2018-02-27
#
#                                              infoLink  \
# 0   http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1   http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2   http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 3   http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 4   http://books.google.nl/books?id=399SPgAACAAJ&d...
# 5   http://books.google.nl/books?id=kVqRaiPlx88C&d...
# 6   http://books.google.nl/books?id=mHLTngEACAAJ&d...
# 7   http://books.google.nl/books?id=6HDOwAEACAAJ&d...
# 8   http://books.google.nl/books?id=lmLqAAAACAAJ&d...
# 9   http://books.google.nl/books?id=rbLZugEACAAJ&d...
# 10  http://books.google.nl/books?id=o7izAAAAIAAJ&d...
# 11  http://books.google.nl/books?id=iTueuAAACAAJ&d...
# 12  http://books.google.nl/books?id=tX1IswEACAAJ&d...
# 13  https://play.google.com/store/books/details?id...
# 14  https://play.google.com/store/books/details?id...
#
#                        categories  ratingsCount
# 0     ['Comics & Graphic Novels']           NaN
# 1   ['Biography & Autobiography']           NaN
# 2                    ['Religion']           NaN
# 3                     ['Fiction']           NaN
# 4                         Unknown           NaN
# 5                    ['Religion']           5.0
# 6                         Unknown           NaN
# 7                         Unknown           3.0
# 8   ['Biography & Autobiography']           NaN
# 9              ['Social Science']           NaN
# 10                   ['Religion']           NaN
# 11                  ['Reference']           NaN
# 12        ['Juvenile Nonfiction']           NaN
# 13   ['Technology & Engineering']           NaN
# 14                    ['History']           NaN

# %%
book_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Id                  object
#  1   Title               object
#  2   Price               float64
#  3   User_id             object
#  4   profileName         object
#  5   review/helpfulness  object
#  6   review/score        float64
#  7   review/time         int64
#  8   review/summary      object
#  9   review/text         object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 228.9+ MB

# %%
#Finding Null Values and percentage of Null Values for Book Ratings
print(book_ratings.isnull().sum())
print("\n")
print((book_ratings.isnull().sum()/(len(book_ratings)))*100)
# Out:
# Id                          0
# Title                     208
# Price                 2518829
# User_id                561787
# profileName            561905
# review/helpfulness          0
# review/score                0
# review/time                 0
# review/summary            407
# review/text                 8
# dtype: int64
#
#
# Id                     0.000000
# Title                  0.006933
# Price                 83.960967
# User_id               18.726233
# profileName           18.730167
# review/helpfulness     0.000000
# review/score           0.000000
# review/time            0.000000
# review/summary         0.013567
# review/text            0.000267
# dtype: float64

# %%
#Merging the dataframes
merged = pd.merge(book_data, book_ratings, on = 'Title')

# %%
merged.head(5)
# Out:
#                             Title  \
# 0  Its Only Art If Its Well Hung!
# 1        Dr. Seuss: American Icon
# 2        Dr. Seuss: American Icon
# 3        Dr. Seuss: American Icon
# 4        Dr. Seuss: American Icon
#
#                                          description           authors  \
# 0                                            Unknown  ['Julie Strain']
# 1  Philip Nel takes a fascinating look into the k...    ['Philip Nel']
# 2  Philip Nel takes a fascinating look into the k...    ['Philip Nel']
# 3  Philip Nel takes a fascinating look into the k...    ['Philip Nel']
# 4  Philip Nel takes a fascinating look into the k...    ['Philip Nel']
#
#                                                image  \
# 0  http://books.google.com/books/content?id=DykPA...
# 1  http://books.google.com/books/content?id=IjvHQ...
# 2  http://books.google.com/books/content?id=IjvHQ...
# 3  http://books.google.com/books/content?id=IjvHQ...
# 4  http://books.google.com/books/content?id=IjvHQ...
#
#                                          previewLink  publisher publishedDate  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...    Unknown          1996
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 2  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 3  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 4  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
#
#                                             infoLink  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 3  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 4  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
#
#                       categories  ratingsCount          Id  Price  \
# 0    ['Comics & Graphic Novels']           NaN  1882931173    NaN
# 1  ['Biography & Autobiography']           NaN  0826414346    NaN
# 2  ['Biography & Autobiography']           NaN  0826414346    NaN
# 3  ['Biography & Autobiography']           NaN  0826414346    NaN
# 4  ['Biography & Autobiography']           NaN  0826414346    NaN
#
#           User_id                         profileName review/helpfulness  \
# 0   AVCGYZL8FQQTD               Jim of Oz "jim-of-oz"                7/7
# 1  A30TK6U7DNS82R                       Kevin Killian              10/10
# 2  A3UH4UZ4RSVO82                        John Granger              10/11
# 3  A2MVUWT453QH61  Roy E. Perry "amateur philosopher"                7/7
# 4  A22X4XUPKF66MR     D. H. Richards "ninthwavestore"                3/3
#
#    review/score  review/time                                   review/summary  \
# 0           4.0    940636800           Nice collection of Julie Strain images
# 1           5.0   1095724800                                Really Enjoyed It
# 2           5.0   1078790400  Essential for every personal and Public Library
# 3           4.0   1090713600  Phlip Nel gives silly Seuss a serious treatment
# 4           4.0   1107993600                           Good academic overview
#
#                                          review/text
# 0  This is only for Julie Strain fans. It's a col...
# 1  I don't care much for Dr. Seuss but after read...
# 2  If people become the books they read and if "t...
# 3  Theodore Seuss Geisel (1904-1991), aka &quot;D...
# 4  Philip Nel - Dr. Seuss: American IconThis is b...

# %%
#Dropping Cols which seem to be less important
merged.drop(columns= 'review/time', inplace = True)
merged.drop(columns = 'Price', inplace = True)
merged.drop(columns = 'image', inplace = True)
merged.drop(columns = 'previewLink', inplace = True)
merged.drop(columns = 'infoLink', inplace = True)

# %% [markdown]
# # Feature Engineering

# %%
merged['ratingsCount'] = merged.groupby('Id')['Id'].transform('count')

# %%
merged['avgRating'] = merged.groupby('Id')['review/score'].transform('mean')
merged.head(5)
# Out:
#                             Title  \
# 0  Its Only Art If Its Well Hung!
# 1        Dr. Seuss: American Icon
# 2        Dr. Seuss: American Icon
# 3        Dr. Seuss: American Icon
# 4        Dr. Seuss: American Icon
#
#                                          description           authors  \
# 0                                            Unknown  ['Julie Strain']
# 1  Philip Nel takes a fascinating look into the k...    ['Philip Nel']
# 2  Philip Nel takes a fascinating look into the k...    ['Philip Nel']
# 3  Philip Nel takes a fascinating look into the k...    ['Philip Nel']
# 4  Philip Nel takes a fascinating look into the k...    ['Philip Nel']
#
#    publisher publishedDate                     categories  ratingsCount  \
# 0    Unknown          1996    ['Comics & Graphic Novels']             1
# 1  A&C Black    2005-01-01  ['Biography & Autobiography']             9
# 2  A&C Black    2005-01-01  ['Biography & Autobiography']             9
# 3  A&C Black    2005-01-01  ['Biography & Autobiography']             9
# 4  A&C Black    2005-01-01  ['Biography & Autobiography']             9
#
#            Id         User_id                         profileName  \
# 0  1882931173   AVCGYZL8FQQTD               Jim of Oz "jim-of-oz"
# 1  0826414346  A30TK6U7DNS82R                       Kevin Killian
# 2  0826414346  A3UH4UZ4RSVO82                        John Granger
# 3  0826414346  A2MVUWT453QH61  Roy E. Perry "amateur philosopher"
# 4  0826414346  A22X4XUPKF66MR     D. H. Richards "ninthwavestore"
#
#   review/helpfulness  review/score  \
# 0                7/7           4.0
# 1              10/10           5.0
# 2              10/11           5.0
# 3                7/7           4.0
# 4                3/3           4.0
#
#                                     review/summary  \
# 0           Nice collection of Julie Strain images
# 1                                Really Enjoyed It
# 2  Essential for every personal and Public Library
# 3  Phlip Nel gives silly Seuss a serious treatment
# 4                           Good academic overview
#
#                                          review/text  avgRating
# 0  This is only for Julie Strain fans. It's a col...   4.000000
# 1  I don't care much for Dr. Seuss but after read...   4.555556
# 2  If people become the books they read and if "t...   4.555556
# 3  Theodore Seuss Geisel (1904-1991), aka &quot;D...   4.555556
# 4  Philip Nel - Dr. Seuss: American IconThis is b...   4.555556

# %%
#Taking the subset of original data
subset = merged.sample(n = 50000, random_state= 42)
print(subset)
# Out:
#                                                      Title  \
# 2945667  A Christmas Carol, in Prose: Being a Ghost Sto...
# 2352586                                Priest Kings of Gor
# 1531260  Earth Angels: A Pocket Guide for Incarnated An...
# 941910                       The Fascinating King's Gambit
# 2582125  THE RED BADGE OF COURAGE: AN EPISODE OF THE AM...
# ...                                                    ...
# 1333972                              Operations Management
# 62331                                             Betrayed
# 1229382                                  Little fur family
# 1298893                                Crime & punishment;
# 2862993  The Fabric of the Cosmos: Space, Time, and the...
#
#                                                description  \
# 2945667                                            Unknown
# 2352586      "40th anniversary of the Gorean saga"--Cover.
# 1531260                                            Unknown
# 941910   The Fascinating King's Gambit by Thomas Johans...
# 2582125                                            Unknown
# ...                                                    ...
# 1333972  Stevenson's Operations Management features int...
# 62331    Kundera's essay has been written like a novel....
# 1229382                                            Unknown
# 1298893                                            Unknown
# 2862993  From Brian Greene, one of the world’s leading ...
#
#                          authors               publisher publishedDate  \
# 2945667                  Unknown                 Unknown       Unknown
# 2352586          ['John Norman']              eReads.com    2007-06-01
# 1531260                  Unknown                 Unknown       Unknown
# 941910      ['Thomas Johansson']  Trafford on Demand Pub       2005-01
# 2582125                  Unknown                 Unknown       Unknown
# ...                          ...                     ...           ...
# 1333972  ['William J Stevenson']   McGraw-Hill Education    2017-02-15
# 62331          ['Milan Kundera']           Faber & Faber    2020-11-09
# 1229382                  Unknown                 Unknown       Unknown
# 1298893                  Unknown                 Unknown       Unknown
# 2862993         ['Brian Greene']                 Vintage    2007-12-18
#
#                        categories  ratingsCount          Id         User_id  \
# 2945667                   Unknown          1014  0742623157  A1YKDO084DR45N
# 2352586               ['Fiction']            21  0345210964   AEW52V1F2KOHI
# 1531260                   Unknown            42  1401900488  A2LZKALNA3YZD7
# 941910                  ['Games']            12  1412046475  A3R9HIZV0Y4AWC
# 2582125                   Unknown           426  B000KQ0TCI  A11JA2K3SMNIB4
# ...                           ...           ...         ...             ...
# 1333972  ['Business & Economics']            16  B000K6BULM   AAUZ4BY8GI842
# 62331    ['Literary Collections']            57  B000PDI3WE             NaN
# 1229382                   Unknown            48  B0006ROWGA  A3015UYV3RVQVP
# 1298893                   Unknown           539  B00085ZGFG  A3HP2J79H3QKBM
# 2862993               ['Science']           294  B0001KIH0Y  A15X60NOGL3WDW
#
#                             profileName review/helpfulness  review/score  \
# 2945667                      Will Lentz                1/2           5.0
# 2352586            Lady Penina "Penina"                1/1           4.0
# 1531260             Katelin "barbiegrl"              26/32           5.0
# 941910             Parker Rose "Parker"                2/2           3.0
# 2582125                        bobbyboy                1/2           2.0
# ...                                 ...                ...           ...
# 1333972                    Angeli's Mom                0/1           5.0
# 62331                               NaN              19/25           5.0
# 1229382  Sara Heartlong "grandma-to-be"                2/2           5.0
# 1298893                       Anonymous              24/62           1.0
# 2862993             Miles Hinley "Milo"                0/2           5.0
#
#                                             review/summary  \
# 2945667                   Best reading of Dicken's classic
# 2352586                                    No Bugs Milady?
# 1531260                                     explains a lot
# 941910                       Good Content, Poor Production
# 2582125                     repetitious and needless words
# ...                                                    ...
# 1333972                                    Great condition
# 62331                      For the christian and Jew alike
# 1229382                            Small hands - BIG heart
# 1298893  Buying it was my Crime, Reading it was my Puni...
# 2862993                                     Nice Audiobook
#
#                                                review/text  avgRating
# 2945667  Absolutely, hands down the best reading of Cha...   4.686391
# 2352586  Hello Fringies! It's ME again.Now those of you...   3.904762
# 1531260  Explained a lot of my &quot;weird&quot; behavi...   4.119048
# 941910   A respectable effort on the King's Bishop Gamb...   3.833333
# 2582125  the book was wordy considering it was 1 plot t...   3.624413
# ...                                                    ...        ...
# 1333972  The price was right and it arrived quickly and...   4.375000
# 62331    This book is a very enlightening resource for ...   4.122807
# 1229382  If you cherish Goodnight Moon, you will love t...   4.645833
# 1298893  By the end of the book the voices that Raskiln...   4.393321
# 2862993  Enjoyed this audiobook so much I bought elegan...   4.482993
#
# [50000 rows x 15 columns]

# %%
#Differentiating categorical and numerical variables
cat_cols=subset.select_dtypes(include=['object']).columns
num_cols = subset.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['Title', 'description', 'authors', 'publisher', 'publishedDate',
#        'categories', 'Id', 'User_id', 'profileName', 'review/helpfulness',
#        'review/summary', 'review/text'],
#       dtype='object')
# Numerical Variables:
# ['ratingsCount', 'review/score', 'avgRating']

# %%
#Plotting the Numerical Variables
for col in num_cols:
    print(col)
    print('Skew :', round(subset[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    subset[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=subset[col])
    plt.show()
# Out:
# ratingsCount
# Skew : 3.37
# review/score
# Skew : -1.51
# avgRating
# Skew : -1.45

# %%
# Replace empty strings with 'Unknown'
subset['review/summary'] = subset['review/summary'].replace('', 'Unknown')

# Replace NaN values with 'Unknown' as before
subset['review/summary'] = subset['review/summary'].fillna('Unknown')

# %% [markdown]
# # Model

# %% [markdown]
# Pre-trained Vader model for Sentiment Analysis

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to analyze the sentiment of the review
def get_sentiment_category(review):
    # Get the sentiment score from VADER
    sentiment_score = analyzer.polarity_scores(review)['compound']
    
    # Map sentiment score to sentiment category
    if sentiment_score <= -0.5:
        return 'Poor'
    elif -0.5 < sentiment_score <= 0:
        return 'Average'
    elif 0 < sentiment_score <= 0.5:
        return 'Good'
    elif 0.5 < sentiment_score <= 0.75:
        return 'Very Good'
    else:
        return 'Must Read'

# Apply the function to the reviews column
subset['sentiment_category'] = subset['review/summary'].apply(get_sentiment_category)

# View the DataFrame with sentiment categories
print(subset[['Title', 'review/summary', 'sentiment_category']])
# Out:
#                                                      Title  \
# 2945667  A Christmas Carol, in Prose: Being a Ghost Sto...
# 2352586                                Priest Kings of Gor
# 1531260  Earth Angels: A Pocket Guide for Incarnated An...
# 941910                       The Fascinating King's Gambit
# 2582125  THE RED BADGE OF COURAGE: AN EPISODE OF THE AM...
# ...                                                    ...
# 1333972                              Operations Management
# 62331                                             Betrayed
# 1229382                                  Little fur family
# 1298893                                Crime & punishment;
# 2862993  The Fabric of the Cosmos: Space, Time, and the...
#
#                                             review/summary sentiment_category
# 2945667                   Best reading of Dicken's classic          Very Good
# 2352586                                    No Bugs Milady?            Average
# 1531260                                     explains a lot            Average
# 941910                       Good Content, Poor Production            Average
# 2582125                     repetitious and needless words            Average
# ...                                                    ...                ...
# 1333972                                    Great condition          Very Good
# 62331                      For the christian and Jew alike            Average
# 1229382                            Small hands - BIG heart          Very Good
# 1298893  Buying it was my Crime, Reading it was my Puni...               Poor
# 2862993                                     Nice Audiobook               Good
#
# [50000 rows x 3 columns]

# %%
# Function to map ratings to sentiment categories
def categorize_rating(avgRating):
    if avgRating <= 1:
        return 'Poor'
    elif avgRating < 2 and avgRating > 1:
        return 'Average'
    elif avgRating < 3 and avgRating > 2:
        return 'Good'
    elif avgRating < 4 and avgRating > 3:
        return 'Very Good'
    elif avgRating <= 5 and avgRating > 4:
        return 'Must Read'

# Apply the categorization function to the rating column
subset['sentiment_rating_category'] = subset['avgRating'].apply(categorize_rating)

# View the DataFrame
print(subset[['Title', 'avgRating', 'sentiment_rating_category']])

rating_df = subset[['Title', 'avgRating' , 'sentiment_rating_category', 'review/summary', 'sentiment_category']]
# Out:
#                                                      Title  avgRating  \
# 2945667  A Christmas Carol, in Prose: Being a Ghost Sto...   4.686391
# 2352586                                Priest Kings of Gor   3.904762
# 1531260  Earth Angels: A Pocket Guide for Incarnated An...   4.119048
# 941910                       The Fascinating King's Gambit   3.833333
# 2582125  THE RED BADGE OF COURAGE: AN EPISODE OF THE AM...   3.624413
# ...                                                    ...        ...
# 1333972                              Operations Management   4.375000
# 62331                                             Betrayed   4.122807
# 1229382                                  Little fur family   4.645833
# 1298893                                Crime & punishment;   4.393321
# 2862993  The Fabric of the Cosmos: Space, Time, and the...   4.482993
#
#         sentiment_rating_category
# 2945667                 Must Read
# 2352586                 Very Good
# 1531260                 Must Read
# 941910                  Very Good
# 2582125                 Very Good
# ...                           ...
# 1333972                 Must Read
# 62331                   Must Read
# 1229382                 Must Read
# 1298893                 Must Read
# 2862993                 Must Read
#
# [50000 rows x 3 columns]

# %%
rating_df['Genre'] = subset['categories']
rating_df['Author'] = subset['authors']
# Out:
# /tmp/ipykernel_36/1065863161.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating_df['Genre'] = subset['categories']
# /tmp/ipykernel_36/1065863161.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating_df['Author'] = subset['authors']

# %%
# Remove brackets and single quotes from the 'Genre' column
rating_df['Genre'] = rating_df['Genre'].str.replace(r"[\[\]']", '', regex=True).str.strip()
rating_df['Author'] = rating_df['Author'].str.replace(r"[\[\]']", '', regex=True).str.strip()
# Out:
# /tmp/ipykernel_36/1511598800.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating_df['Genre'] = rating_df['Genre'].str.replace(r"[\[\]']", '', regex=True).str.strip()
# /tmp/ipykernel_36/1511598800.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating_df['Author'] = rating_df['Author'].str.replace(r"[\[\]']", '', regex=True).str.strip()

# %%
# Step 1: Create a mapping of authors to their known genres
# Group by author and aggregate genres into a list
author_genre_map = rating_df.groupby('Author')['Genre'].agg(lambda x: x.mode()[0] if not x.mode().empty else pd.NA).reset_index()



# Step 2: Create a dictionary from the mapping
author_genre_dict = {row['Author']: row['Genre'] for index, row in author_genre_map.iterrows() if row['Genre'] != 'Unknown'}

# Step 3: Fill unknown values in the 'Genre' column
def fill_unknown_genre(row):
    if row['Genre'] == 'Unknown':
        author = row['Author']
        if author in author_genre_dict:
            # Choose the first genre from the list for simplicity
            return author_genre_dict[author][0]
    return row['Genre']

# Apply the function to fill unknown genres
rating_df['Genre'] = rating_df.apply(fill_unknown_genre, axis=1)
# Out:
# /tmp/ipykernel_36/520015360.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating_df['Genre'] = rating_df.apply(fill_unknown_genre, axis=1)

# %%
rating_df.sort_values(by = "avgRating", ascending = False)
# Out:
#                                                      Title  avgRating  \
# 1272280         The Keystone Kid: Tales of Early Hollywood        5.0
# 1228711                                  Racquetball Today        5.0
# 521395                                 The happy orpheline        5.0
# 1992341  No Man Stands Alone: The True Story of Barney ...        5.0
# 2894943  Three to zero;: The story of the birth and dea...        5.0
# ...                                                    ...        ...
# 1597845                           Another Story: A Novella        1.0
# 2745446                         1,000 Crazy Jokes for Kids        1.0
# 2649487                  Cigar Bizarre: An Unusual History        1.0
# 1772059   The Art of Gelato: Italian Desserts and Pastries        1.0
# 1150658  Activated Sludge: Treatment of Industrial Wast...        1.0
#
#         sentiment_rating_category  \
# 1272280                 Must Read
# 1228711                 Must Read
# 521395                  Must Read
# 1992341                 Must Read
# 2894943                 Must Read
# ...                           ...
# 1597845                      Poor
# 2745446                      Poor
# 2649487                      Poor
# 1772059                      Poor
# 1150658                      Poor
#
#                                             review/summary sentiment_category  \
# 1272280              Awesome book about Hollywood History!          Very Good
# 1228711                                     Best technique          Very Good
# 521395   1st in a Series of 2--Lively tale of a French ...            Average
# 1992341                 Incredible guts of a true champion          Must Read
# 2894943             An unexpected study in union politics.            Average
# ...                                                    ...                ...
# 1597845                                         Unreadable            Average
# 2745446                              Can you give NO STAR?            Average
# 2649487                     Read the description carefully               Good
# 1772059            Fans of non-fat powdered milk, rejoice!               Good
# 1150658                              waste water treatment            Average
#
#                             Genre                              Author
# 1272280           Performing Arts                          Coy Watson
# 1228711       Sports & Recreation         Lynn Adams, Erwin Goldbloom
# 521395                     France              Natalie Savage Carlson
# 1992341            Drug addiction        Barney Ross, Martin Abramson
# 2894943       American newspapers                         Joseph Sage
# ...                           ...                                 ...
# 1597845                   Fiction                   Tatiana de Rosnay
# 2745446     English wit and humor                   Michael Johnstone
# 2649487            Social Science                      Philip Collins
# 1772059                   Cooking                   Francisco Daniele
# 1150658  Technology & Engineering  Wesley Eckenfelder, Jack Musterman
#
# [50000 rows x 7 columns]

# %%
# Count the occurrences of each sentiment category
sentiment_counts = rating_df['sentiment_rating_category'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(sentiment_counts, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette("pastel"))
plt.title('Percentage of Books Rated from Poor to Must Read')
plt.axis('equal')  
plt.show()

# %% [markdown]
# # Recommender System

# %%
ordinal_map = { 'Poor' : 1, 'Average' : 2, 'Good' : 3, 'Very Good' : 4, 'Must Read' : 5}

# %%
rating_df['Rating_Ordinal'] = rating_df['sentiment_rating_category'].replace(ordinal_map)
rating_df
# Out:
# /tmp/ipykernel_36/3202203064.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   rating_df['Rating_Ordinal'] = rating_df['sentiment_rating_category'].replace(ordinal_map)
# /tmp/ipykernel_36/3202203064.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating_df['Rating_Ordinal'] = rating_df['sentiment_rating_category'].replace(ordinal_map)
#                                                      Title  avgRating  \
# 2945667  A Christmas Carol, in Prose: Being a Ghost Sto...   4.686391
# 2352586                                Priest Kings of Gor   3.904762
# 1531260  Earth Angels: A Pocket Guide for Incarnated An...   4.119048
# 941910                       The Fascinating King's Gambit   3.833333
# 2582125  THE RED BADGE OF COURAGE: AN EPISODE OF THE AM...   3.624413
# ...                                                    ...        ...
# 1333972                              Operations Management   4.375000
# 62331                                             Betrayed   4.122807
# 1229382                                  Little fur family   4.645833
# 1298893                                Crime & punishment;   4.393321
# 2862993  The Fabric of the Cosmos: Space, Time, and the...   4.482993
#
#         sentiment_rating_category  \
# 2945667                 Must Read
# 2352586                 Very Good
# 1531260                 Must Read
# 941910                  Very Good
# 2582125                 Very Good
# ...                           ...
# 1333972                 Must Read
# 62331                   Must Read
# 1229382                 Must Read
# 1298893                 Must Read
# 2862993                 Must Read
#
#                                             review/summary sentiment_category  \
# 2945667                   Best reading of Dicken's classic          Very Good
# 2352586                                    No Bugs Milady?            Average
# 1531260                                     explains a lot            Average
# 941910                       Good Content, Poor Production            Average
# 2582125                     repetitious and needless words            Average
# ...                                                    ...                ...
# 1333972                                    Great condition          Very Good
# 62331                      For the christian and Jew alike            Average
# 1229382                            Small hands - BIG heart          Very Good
# 1298893  Buying it was my Crime, Reading it was my Puni...               Poor
# 2862993                                     Nice Audiobook               Good
#
#                         Genre               Author  Rating_Ordinal
# 2945667               Unknown              Unknown             5.0
# 2352586               Fiction          John Norman             4.0
# 1531260               Unknown              Unknown             5.0
# 941910                  Games     Thomas Johansson             4.0
# 2582125               Unknown              Unknown             4.0
# ...                       ...                  ...             ...
# 1333972  Business & Economics  William J Stevenson             5.0
# 62331    Literary Collections        Milan Kundera             5.0
# 1229382               Unknown              Unknown             5.0
# 1298893               Unknown              Unknown             5.0
# 2862993               Science         Brian Greene             5.0
#
# [50000 rows x 8 columns]

# %%
# Create an ordinal mapping for genres
genre_mapping = {genre: idx for idx, genre in enumerate(rating_df['Genre'].unique())}
rating_df['Genre_Encoded'] = rating_df['Genre'].map(genre_mapping)
# Out:
# /tmp/ipykernel_36/1482338223.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rating_df['Genre_Encoded'] = rating_df['Genre'].map(genre_mapping)

# %%
rating_df
# Out:
#                                                      Title  avgRating  \
# 2945667  A Christmas Carol, in Prose: Being a Ghost Sto...   4.686391
# 2352586                                Priest Kings of Gor   3.904762
# 1531260  Earth Angels: A Pocket Guide for Incarnated An...   4.119048
# 941910                       The Fascinating King's Gambit   3.833333
# 2582125  THE RED BADGE OF COURAGE: AN EPISODE OF THE AM...   3.624413
# ...                                                    ...        ...
# 1333972                              Operations Management   4.375000
# 62331                                             Betrayed   4.122807
# 1229382                                  Little fur family   4.645833
# 1298893                                Crime & punishment;   4.393321
# 2862993  The Fabric of the Cosmos: Space, Time, and the...   4.482993
#
#         sentiment_rating_category  \
# 2945667                 Must Read
# 2352586                 Very Good
# 1531260                 Must Read
# 941910                  Very Good
# 2582125                 Very Good
# ...                           ...
# 1333972                 Must Read
# 62331                   Must Read
# 1229382                 Must Read
# 1298893                 Must Read
# 2862993                 Must Read
#
#                                             review/summary sentiment_category  \
# 2945667                   Best reading of Dicken's classic          Very Good
# 2352586                                    No Bugs Milady?            Average
# 1531260                                     explains a lot            Average
# 941910                       Good Content, Poor Production            Average
# 2582125                     repetitious and needless words            Average
# ...                                                    ...                ...
# 1333972                                    Great condition          Very Good
# 62331                      For the christian and Jew alike            Average
# 1229382                            Small hands - BIG heart          Very Good
# 1298893  Buying it was my Crime, Reading it was my Puni...               Poor
# 2862993                                     Nice Audiobook               Good
#
#                         Genre               Author  Rating_Ordinal  \
# 2945667               Unknown              Unknown             5.0
# 2352586               Fiction          John Norman             4.0
# 1531260               Unknown              Unknown             5.0
# 941910                  Games     Thomas Johansson             4.0
# 2582125               Unknown              Unknown             4.0
# ...                       ...                  ...             ...
# 1333972  Business & Economics  William J Stevenson             5.0
# 62331    Literary Collections        Milan Kundera             5.0
# 1229382               Unknown              Unknown             5.0
# 1298893               Unknown              Unknown             5.0
# 2862993               Science         Brian Greene             5.0
#
#          Genre_Encoded
# 2945667              0
# 2352586              1
# 1531260              0
# 941910               2
# 2582125              0
# ...                ...
# 1333972              7
# 62331              107
# 1229382              0
# 1298893              0
# 2862993             75
#
# [50000 rows x 9 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Sample a smaller subset for testing
sampled_df = rating_df.sample(n=50000, random_state=42)  # Adjust sample size as necessary
pivot_table = sampled_df.pivot_table(index='Title', columns='Genre_Encoded', values='Rating_Ordinal').fillna(0)
item_similarity = cosine_similarity(pivot_table)


# Create a DataFrame for similarity scores
similarity_df = pd.DataFrame(item_similarity, index=pivot_table.index, columns=pivot_table.index)

# %%
def recommend_books_by_genre(genre, sampled_df, similarity_df, genre_mapping, top_n=10):
    if genre not in genre_mapping:
        return "Genre not found."
    
    # Get the encoded genre value
    encoded_genre = genre_mapping[genre]
    
    # Filter books of the selected genre
    genre_books = sampled_df[sampled_df['Genre_Encoded'] == encoded_genre]
    
    if genre_books.empty:
        return "No books found for this genre."

    # Get recommendations based on the first book in the genre
    recommendations = similarity_df.loc[genre_books['Title'].iloc[0]].sort_values(ascending=False)
    
    # Exclude books already in the genre
    recommendations = recommendations[~recommendations.index.isin(genre_books['Title'])]
    
    return recommendations.head(top_n).index.tolist()

# %%
while True:
    user_genre = input("Enter a genre (or type 'exit' to quit): ").strip()
    
    if user_genre.lower() == 'exit':
        break
    
    recommended_books = recommend_books_by_genre(user_genre, sampled_df, similarity_df, genre_mapping)
    
    if isinstance(recommended_books, list):
        print(f"Top recommendations for '{user_genre}':")
        for book in recommended_books:
            print(f"- {book}")
    else:
        print(recommended_books)
# Out:
# Enter a genre (or type 'exit' to quit):  Fantasy
# Top recommendations for 'Fantasy':
# - "A" IS FOR ALIBI
# - THE RED BADGE OF COURAGE: AN EPISODE OF THE AMERICAN CIVIL WAR.
# - THE RISING SUN - TWO VOLUMES
# - THE RISE OF SILAS LAPHAM
# - THE RISE AND FALL ON THE THIRD REICH
# - THE RIGHT WEIGH: SIX STEPS TO PERMANENT WEIGHT LOSS USED BY MORE THAN 100,000 PEOPLE.
# - THE RIDDLE OF THE SANDS: A Record of Secret Service
# - THE REVOLUTIONARY CAREER OF MAXIMILIEN ROBESPIERRE
# - THE PRINT
# - THE PRIZE; THE EPIC QUEST FOR OIL, MONEY, AND POWER.
# Enter a genre (or type 'exit' to quit):  Fiction
# Top recommendations for 'Fiction':
# - Stories for a Teen's Heart: Book 3
# - Stowaway to the Mushroom Planet
# - Straddling the Borders: The Year I Grew Up in Italy
# - The Battle of the Somme: A Topographical History
# - Vermeer ([Skira color prints])
# - Storytelling
# - Story of the Treasure Seekers, The
# - What Happens When Women Pray
# - Storm in the Mountains: Thomas' Confederate Legion of Cherokee Indians and Mountaineers
# - Vermeer's Riddle Revealed: The Sphinx, the Jester, and the Grail Geometry: Robert A. diCurcio's Analysis of Vermeer's Pictorial Compositions
